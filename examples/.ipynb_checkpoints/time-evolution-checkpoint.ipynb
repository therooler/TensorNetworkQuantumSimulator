# %%
using TensorNetworkQuantumSimulator
const TN = TensorNetworkQuantumSimulator

using ITensorNetworks

using NamedGraphs.NamedGraphGenerators: named_grid

# %%
nx = 5
ny = 5
nq = nx * ny

# the graph is your main friend in working with the TNs
g = named_grid((nx, ny))
# Out:
# NamedGraphs.NamedGraph{Tuple{Int64, Int64}} with 25 vertices:
# 25-element NamedGraphs.OrderedDictionaries.OrderedIndices{Tuple{Int64, Int64}}:
#  (1, 1)
#  (2, 1)
#  (3, 1)
#  (4, 1)
#  (5, 1)
#  (1, 2)
#  (2, 2)
#  (3, 2)
#  (4, 2)
#  (5, 2)
#  (1, 3)
#  (2, 3)
#  (3, 3)
#  (4, 3)
#  (5, 3)
#  (1, 4)
#  (2, 4)
#  (3, 4)
#  (4, 4)
#  (5, 4)
#  (1, 5)
#  (2, 5)
#  (3, 5)
#  (4, 5)
#  (5, 5)
#
# and 40 edge(s):
# (1, 1) => (2, 1)
# (1, 1) => (1, 2)
# (2, 1) => (3, 1)
# (2, 1) => (2, 2)
# (3, 1) => (4, 1)
# (3, 1) => (3, 2)
# (4, 1) => (5, 1)
# (4, 1) => (4, 2)
# (5, 1) => (5, 2)
# (1, 2) => (2, 2)
# (1, 2) => (1, 3)
# (2, 2) => (3, 2)
# (2, 2) => (2, 3)
# (3, 2) => (4, 2)
# (3, 2) => (3, 3)
# (4, 2) => (5, 2)
# (4, 2) => (4, 3)
# (5, 2) => (5, 3)
# (1, 3) => (2, 3)
# (1, 3) => (1, 4)
# (2, 3) => (3, 3)
# (2, 3) => (2, 4)
# (3, 3) => (4, 3)
# (3, 3) => (3, 4)
# (4, 3) => (5, 3)
# (4, 3) => (4, 4)
# (5, 3) => (5, 4)
# (1, 4) => (2, 4)
# (1, 4) => (1, 5)
# (2, 4) => (3, 4)
# (2, 4) => (2, 5)
# (3, 4) => (4, 4)
# (3, 4) => (3, 5)
# (4, 4) => (5, 4)
# (4, 4) => (4, 5)
# (5, 4) => (5, 5)
# (1, 5) => (2, 5)
# (2, 5) => (3, 5)
# (3, 5) => (4, 5)
# (4, 5) => (5, 5)

# %%
dt = 0.05

hx = 1.0
hz = 0.8
J = 0.5

# pauli rotations are tuples like `(pauli_string, [site_labels], parameter)`
layer = []
append!(layer, ("X", [v], 2*hx*dt) for v in TN.vertices(g))
append!(layer, ("Z", [v], 2*hz*dt) for v in TN.vertices(g))
append!(layer, ("ZZ", pair, 2*J*dt) for pair in TN.graphtotopology(g));

# %%
# observables are tuples like `(pauli_string, [site_labels], optional:coefficient)`
# it's important that the `site_labels` match the names of the vertices of the graph `g`
obs = ("Z", [(3, 3)])  # right in the middle
# Out:
# ("Z", [(3, 3)])

# %%
# the number of circuit layers
nl = 50
# Out:
# 50

# %%
# the initial state
ψ = TN.zerostate(g)

# an array to keep track of expectations
expectations = Float64[real(TN.expect(ψ, obs))]

# evolve! The first evaluation will take significantly longer because of compulation.
for l in 1:nl
    #printing
    println("Layer $l")

    # apply layer
    t = @timed ψ = TN.apply(layer, ψ);

    # push expectation to list
    push!(expectations, real(TN.expect(ψ, obs)))

    # printing
    println("    Took time: $(t.time) [s]. Max bond dimension: $(ITensorNetworks.maxlinkdim(ψ))")
end
# Out:
# Layer 1
#     Took time: 53.538128775 [s]. Max bond dimension: 2
# Layer 2
#     Took time: 0.567024184 [s]. Max bond dimension: 2
# Layer 3
#     Took time: 0.651966063 [s]. Max bond dimension: 2
# Layer 4
#     Took time: 0.602523966 [s]. Max bond dimension: 2
# Layer 5
#     Took time: 0.65432837 [s]. Max bond dimension: 2
# Layer 6
#     Took time: 0.575452691 [s]. Max bond dimension: 2
# Layer 7
#     Took time: 0.49720293 [s]. Max bond dimension: 2
# Layer 8
#     Took time: 0.61732744 [s]. Max bond dimension: 3
# Layer 9
#     Took time: 0.59818386 [s]. Max bond dimension: 3
# Layer 10
#     Took time: 0.491830946 [s]. Max bond dimension: 3
# Layer 11
#     Took time: 0.451494004 [s]. Max bond dimension: 3
# Layer 12
#     Took time: 0.458275004 [s]. Max bond dimension: 4
# Layer 13
#     Took time: 0.464292399 [s]. Max bond dimension: 4
# Layer 14
#     Took time: 0.465641487 [s]. Max bond dimension: 4
# Layer 15
#     Took time: 0.490792415 [s]. Max bond dimension: 4
# Layer 16
#     Took time: 0.467311954 [s]. Max bond dimension: 4
# Layer 17
#     Took time: 0.470283782 [s]. Max bond dimension: 4
# Layer 18
#     Took time: 0.508164446 [s]. Max bond dimension: 4
# Layer 19
#     Took time: 0.476994102 [s]. Max bond dimension: 5
# Layer 20
#     Took time: 0.516868151 [s]. Max bond dimension: 5
# Layer 21
#     Took time: 0.543561173 [s]. Max bond dimension: 5
# Layer 22
#     Took time: 0.613833405 [s]. Max bond dimension: 6
# Layer 23
#     Took time: 0.563206919 [s]. Max bond dimension: 6
# Layer 24
#     Took time: 0.567814666 [s]. Max bond dimension: 6
# Layer 25
#     Took time: 0.578684522 [s]. Max bond dimension: 6
# Layer 26
#     Took time: 0.59536259 [s]. Max bond dimension: 7
# Layer 27
#     Took time: 0.665709558 [s]. Max bond dimension: 7
# Layer 28
#     Took time: 0.751878273 [s]. Max bond dimension: 8
# Layer 29
#     Took time: 0.920963311 [s]. Max bond dimension: 8
# Layer 30
#     Took time: 1.060746036 [s]. Max bond dimension: 8
# Layer 31
#     Took time: 0.971025117 [s]. Max bond dimension: 8
# Layer 32
#     Took time: 1.051785686 [s]. Max bond dimension: 9
# Layer 33
#     Took time: 1.20355136 [s]. Max bond dimension: 9
# Layer 34
#     Took time: 1.430403838 [s]. Max bond dimension: 10
# Layer 35
#     Took time: 1.660943526 [s]. Max bond dimension: 10
# Layer 36
#     Took time: 1.915219838 [s]. Max bond dimension: 10
# Layer 37
#     Took time: 1.952709019 [s]. Max bond dimension: 10
# Layer 38
#     Took time: 1.987089498 [s]. Max bond dimension: 10
# Layer 39
#     Took time: 2.083210562 [s]. Max bond dimension: 10
# Layer 40
#     Took time: 2.177154921 [s]. Max bond dimension: 11
# Layer 41
#     Took time: 2.235216219 [s]. Max bond dimension: 11
# Layer 42
#     Took time: 2.593317732 [s]. Max bond dimension: 12
# Layer 43
#     Took time: 3.211898436 [s]. Max bond dimension: 12
# Layer 44
#     Took time: 4.547646849 [s]. Max bond dimension: 13
# Layer 45
#     Took time: 4.859507555 [s]. Max bond dimension: 13
# Layer 46
#     Took time: 5.426083274 [s]. Max bond dimension: 14
# Layer 47
#     Took time: 6.194165609 [s]. Max bond dimension: 15
# Layer 48
#     Took time: 6.621540468 [s]. Max bond dimension: 15
# Layer 49
#     Took time: 7.168390645 [s]. Max bond dimension: 16
# Layer 50
#     Took time: 7.674742932 [s]. Max bond dimension: 16

# %%
using Plots
plot((0:nl) .* dt, expectations, xlabel="t", ylabel="Expectation", lw=2, label="Just believe propagation")

# %%
## A few more advanced options
# we will still do exactly the same evolution but also do loop correction for expectation values

# %%
# max bond dimension for the TN
# we will use enough and just see how
apply_kwargs = (maxdim=20, cutoff=1e-10, normalize=false)

# BP cache parameters
bp_update_kwargs =(maxiter=20, tol=1e-6, message_update=ms -> TN.make_eigs_real.(TN.default_message_update(ms)))
# Out:
# (maxiter = 20, tol = 1.0e-6, message_update = var"#7#8"())

# %%
# the initial state
ψ = TN.zerostate(g)

# create the BP cache manually
ψψ = TN.build_bp_cache(ψ; bp_update_kwargs...)

# an array to keep track of expectations
expectations_advanced = Float64[real(TN.expect(ψ, obs))]

# evolve! The first evaluation will take significantly longer because of compulation.
for l in 1:nl
    println("Layer $l")

    # pass BP cache manually
    # only update cache every `update_every` overlapping 2-qubit gates
    t1 = @timed ψ, ψψ = TN.apply(layer, ψ, ψψ; apply_kwargs, update_every=1, verbose=false);
    
    ## could also update outside 
    # t2 = @timed ψψ = TN.update(ψψ; bp_update_kwargs...)

    # push expectation to list
    push!(expectations_advanced, real(TN.expect(ψ, obs; max_loop_size=4)))  # with some loop correction

    
    println("    Took time: $(t1.time) [s]. Max bond dimension: $(ITensorNetworks.maxlinkdim(ψ))")
end
# Out:
# Layer 1
#     Took time: 0.995044994 [s]. Max bond dimension: 2
# Layer 2
#     Took time: 0.408046111 [s]. Max bond dimension: 2
# Layer 3
#     Took time: 0.463077274 [s]. Max bond dimension: 2
# Layer 4
#     Took time: 0.422181284 [s]. Max bond dimension: 2
# Layer 5
#     Took time: 0.41466629 [s]. Max bond dimension: 2
# Layer 6
#     Took time: 0.454596565 [s]. Max bond dimension: 2
# Layer 7
#     Took time: 0.503809349 [s]. Max bond dimension: 2
# Layer 8
#     Took time: 0.489915597 [s]. Max bond dimension: 3
# Layer 9
#     Took time: 0.368932799 [s]. Max bond dimension: 3
# Layer 10
#     Took time: 0.39901244 [s]. Max bond dimension: 3
# Layer 11
#     Took time: 0.445214382 [s]. Max bond dimension: 3
# Layer 12
#     Took time: 0.430995937 [s]. Max bond dimension: 4
# Layer 13
#     Took time: 0.419971124 [s]. Max bond dimension: 4
# Layer 14
#     Took time: 0.456202128 [s]. Max bond dimension: 4
# Layer 15
#     Took time: 0.468556802 [s]. Max bond dimension: 4
# Layer 16
#     Took time: 0.439062351 [s]. Max bond dimension: 4
# Layer 17
#     Took time: 0.417825135 [s]. Max bond dimension: 4
# Layer 18
#     Took time: 0.420449162 [s]. Max bond dimension: 4
# Layer 19
#     Took time: 0.445061151 [s]. Max bond dimension: 5
# Layer 20
#     Took time: 0.443067933 [s]. Max bond dimension: 5
# Layer 21
#     Took time: 0.456808595 [s]. Max bond dimension: 5
# Layer 22
#     Took time: 0.455255999 [s]. Max bond dimension: 6
# Layer 23
#     Took time: 0.512248824 [s]. Max bond dimension: 6
# Layer 24
#     Took time: 0.604748846 [s]. Max bond dimension: 6
# Layer 25
#     Took time: 0.614237763 [s]. Max bond dimension: 6
# Layer 26
#     Took time: 0.532927084 [s]. Max bond dimension: 7
# Layer 27
#     Took time: 0.669554474 [s]. Max bond dimension: 7
# Layer 28
#     Took time: 0.933561638 [s]. Max bond dimension: 8
# Layer 29
#     Took time: 0.873918873 [s]. Max bond dimension: 8
# Layer 30
#     Took time: 0.942251061 [s]. Max bond dimension: 8
# Layer 31
#     Took time: 0.913007658 [s]. Max bond dimension: 8
# Layer 32
#     Took time: 1.025391629 [s]. Max bond dimension: 9
# Layer 33
#     Took time: 1.172568628 [s]. Max bond dimension: 9
# Layer 34
#     Took time: 1.398368578 [s]. Max bond dimension: 10
# Layer 35
#     Took time: 1.460815857 [s]. Max bond dimension: 10
# Layer 36
#     Took time: 1.614577172 [s]. Max bond dimension: 10
# Layer 37
#     Took time: 1.692207058 [s]. Max bond dimension: 10
# Layer 38
#     Took time: 1.771594057 [s]. Max bond dimension: 10
# Layer 39
#     Took time: 1.739961046 [s]. Max bond dimension: 10
# Layer 40
#     Took time: 1.812449304 [s]. Max bond dimension: 11
# Layer 41
#     Took time: 1.991185543 [s]. Max bond dimension: 11
# Layer 42
#     Took time: 2.164500698 [s]. Max bond dimension: 12
# Layer 43
#     Took time: 2.44565063 [s]. Max bond dimension: 12
# Layer 44
#     Took time: 2.580614326 [s]. Max bond dimension: 13
# Layer 45
#     Took time: 3.501150809 [s]. Max bond dimension: 13
# Layer 46
#     Took time: 3.637265667 [s]. Max bond dimension: 14
# Layer 47
#     Took time: 4.145952954 [s]. Max bond dimension: 15
# Layer 48
#     Took time: 4.190783104 [s]. Max bond dimension: 15
# Layer 49
#     Took time: 4.669278309 [s]. Max bond dimension: 16
# Layer 50
#     Took time: 4.929022925 [s]. Max bond dimension: 16

# %%
plot((0:nl) .* dt, expectations, xlabel="t", ylabel="Expectation", lw=2, label="Just believe propagation")
plot!((0:nl) .* dt, expectations_advanced, lw=2, label="With some loop corrections")
