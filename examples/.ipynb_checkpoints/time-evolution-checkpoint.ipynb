# %%
using TensorNetworkQuantumSimulator
const TN = TensorNetworkQuantumSimulator

using ITensorNetworks

using NamedGraphs.NamedGraphGenerators: named_grid
# Out:
# [ Info: Precompiling TensorNetworkQuantumSimulator [4de3b72a-362e-43dd-83ff-3f381eda9f9c] (cache misses: include_dependency fsize change (2))
# WARNING: Method definition expect(ITensorNetworks.BeliefPropagationCache{PTN, MTS, DM} where DM where MTS where PTN, Any) in module TensorNetworkQuantumSimulator at /home/manuel/.julia/dev/TensorNetworkQuantumSimulator/src/expect.jl:16 overwritten at /home/manuel/.julia/dev/TensorNetworkQuantumSimulator/src/expect.jl:23.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# ┌ Info: Skipping precompilation due to precompilable error. Importing TensorNetworkQuantumSimulator [4de3b72a-362e-43dd-83ff-3f381eda9f9c].
# └   exception = Error when precompiling module, potentially caused by a __precompile__(false) declaration in the module.

# %%
nx = 5
ny = 5
nq = nx * ny

# the graph is your main friend in working with the TNs
g = named_grid((nx, ny))
# Out:
# NamedGraphs.NamedGraph{Tuple{Int64, Int64}} with 25 vertices:
# 25-element NamedGraphs.OrderedDictionaries.OrderedIndices{Tuple{Int64, Int64}}:
#  (1, 1)
#  (2, 1)
#  (3, 1)
#  (4, 1)
#  (5, 1)
#  (1, 2)
#  (2, 2)
#  (3, 2)
#  (4, 2)
#  (5, 2)
#  (1, 3)
#  (2, 3)
#  (3, 3)
#  (4, 3)
#  (5, 3)
#  (1, 4)
#  (2, 4)
#  (3, 4)
#  (4, 4)
#  (5, 4)
#  (1, 5)
#  (2, 5)
#  (3, 5)
#  (4, 5)
#  (5, 5)
#
# and 40 edge(s):
# (1, 1) => (2, 1)
# (1, 1) => (1, 2)
# (2, 1) => (3, 1)
# (2, 1) => (2, 2)
# (3, 1) => (4, 1)
# (3, 1) => (3, 2)
# (4, 1) => (5, 1)
# (4, 1) => (4, 2)
# (5, 1) => (5, 2)
# (1, 2) => (2, 2)
# (1, 2) => (1, 3)
# (2, 2) => (3, 2)
# (2, 2) => (2, 3)
# (3, 2) => (4, 2)
# (3, 2) => (3, 3)
# (4, 2) => (5, 2)
# (4, 2) => (4, 3)
# (5, 2) => (5, 3)
# (1, 3) => (2, 3)
# (1, 3) => (1, 4)
# (2, 3) => (3, 3)
# (2, 3) => (2, 4)
# (3, 3) => (4, 3)
# (3, 3) => (3, 4)
# (4, 3) => (5, 3)
# (4, 3) => (4, 4)
# (5, 3) => (5, 4)
# (1, 4) => (2, 4)
# (1, 4) => (1, 5)
# (2, 4) => (3, 4)
# (2, 4) => (2, 5)
# (3, 4) => (4, 4)
# (3, 4) => (3, 5)
# (4, 4) => (5, 4)
# (4, 4) => (4, 5)
# (5, 4) => (5, 5)
# (1, 5) => (2, 5)
# (2, 5) => (3, 5)
# (3, 5) => (4, 5)
# (4, 5) => (5, 5)

# %%
dt = 0.05

hx = 1.0
hz = 0.8
J = 0.5

# pauli rotations are tuples like `(pauli_string, [site_labels], parameter)`
layer = []
append!(layer, ("X", [v], 2*hx*dt) for v in TN.vertices(g))
append!(layer, ("Z", [v], 2*hz*dt) for v in TN.vertices(g))
append!(layer, ("ZZ", pair, 2*J*dt) for pair in TN.graphtotopology(g));

# %%
# observables are tuples like `(pauli_string, [site_labels], optional:coefficient)`
# it's important that the `site_labels` match the names of the vertices of the graph `g`
obs = ("Z", [(3, 3)])  # right in the middle
# Out:
# ("Z", [(3, 3)])

# %%
# the number of circuit layers
nl = 50
# Out:
# 50

# %%
# the initial state
ψ = TN.zerostate(g)

# an array to keep track of expectations
expectations = Float64[real(TN.expect(ψ, obs))]

# evolve! The first evaluation will take significantly longer because of compulation.
for l in 1:nl
    #printing
    println("Layer $l")

    # apply layer
    t = @timed ψ = TN.apply(layer, ψ);

    # push expectation to list
    push!(expectations, real(TN.expect(ψ, obs)))

    # printing
    println("    Took time: $(t.time) [s]. Max bond dimension: $(ITensorNetworks.maxlinkdim(ψ))")
end
# Out:
# Layer 1
#     Took time: 66.56913894 [s]. Max bond dimension: 2
# Layer 2
#     Took time: 0.689563687 [s]. Max bond dimension: 2
# Layer 3
#     Took time: 0.625228818 [s]. Max bond dimension: 2
# Layer 4
#     Took time: 0.633324914 [s]. Max bond dimension: 2
# Layer 5
#     Took time: 0.61374681 [s]. Max bond dimension: 2
# Layer 6
#     Took time: 0.606969536 [s]. Max bond dimension: 2
# Layer 7
#     Took time: 0.605310023 [s]. Max bond dimension: 2
# Layer 8
#     Took time: 0.632045249 [s]. Max bond dimension: 3
# Layer 9
#     Took time: 0.633098475 [s]. Max bond dimension: 3
# Layer 10
#     Took time: 0.620759024 [s]. Max bond dimension: 3
# Layer 11
#     Took time: 0.618934407 [s]. Max bond dimension: 3
# Layer 12
#     Took time: 0.647949882 [s]. Max bond dimension: 4
# Layer 13
#     Took time: 0.682247469 [s]. Max bond dimension: 4
# Layer 14
#     Took time: 0.701739751 [s]. Max bond dimension: 4
# Layer 15
#     Took time: 0.673529751 [s]. Max bond dimension: 4
# Layer 16
#     Took time: 0.66922955 [s]. Max bond dimension: 4
# Layer 17
#     Took time: 0.687656044 [s]. Max bond dimension: 4
# Layer 18
#     Took time: 0.672949979 [s]. Max bond dimension: 4
# Layer 19
#     Took time: 0.685784813 [s]. Max bond dimension: 5
# Layer 20
#     Took time: 0.708854516 [s]. Max bond dimension: 5
# Layer 21
#     Took time: 0.722613067 [s]. Max bond dimension: 5
# Layer 22
#     Took time: 0.748921105 [s]. Max bond dimension: 6
# Layer 23
#     Took time: 0.778763218 [s]. Max bond dimension: 6
# Layer 24
#     Took time: 0.800622671 [s]. Max bond dimension: 6
# Layer 25
#     Took time: 0.825870397 [s]. Max bond dimension: 6
# Layer 26
#     Took time: 0.835479475 [s]. Max bond dimension: 7
# Layer 27
#     Took time: 0.925411231 [s]. Max bond dimension: 7
# Layer 28
#     Took time: 1.062850976 [s]. Max bond dimension: 8
# Layer 29
#     Took time: 1.057201905 [s]. Max bond dimension: 8
# Layer 30
#     Took time: 1.130890045 [s]. Max bond dimension: 8
# Layer 31
#     Took time: 1.193003804 [s]. Max bond dimension: 8
# Layer 32
#     Took time: 1.195607451 [s]. Max bond dimension: 9
# Layer 33
#     Took time: 1.238300311 [s]. Max bond dimension: 9
# Layer 34
#     Took time: 1.393175804 [s]. Max bond dimension: 10
# Layer 35
#     Took time: 1.490279986 [s]. Max bond dimension: 10
# Layer 36
#     Took time: 1.554051124 [s]. Max bond dimension: 10
# Layer 37
#     Took time: 1.608827437 [s]. Max bond dimension: 10
# Layer 38
#     Took time: 1.549658676 [s]. Max bond dimension: 10
# Layer 39
#     Took time: 1.549993272 [s]. Max bond dimension: 10
# Layer 40
#     Took time: 1.662376949 [s]. Max bond dimension: 11
# Layer 41
#     Took time: 1.84466805 [s]. Max bond dimension: 11
# Layer 42
#     Took time: 1.856775201 [s]. Max bond dimension: 12
# Layer 43
#     Took time: 2.181087619 [s]. Max bond dimension: 12
# Layer 44
#     Took time: 2.392651838 [s]. Max bond dimension: 13
# Layer 45
#     Took time: 2.704079257 [s]. Max bond dimension: 13
# Layer 46
#     Took time: 3.004505067 [s]. Max bond dimension: 14
# Layer 47
#     Took time: 3.281297457 [s]. Max bond dimension: 15
# Layer 48
#     Took time: 3.636213669 [s]. Max bond dimension: 15
# Layer 49
#     Took time: 4.107755346 [s]. Max bond dimension: 16
# Layer 50
#     Took time: 4.672136337 [s]. Max bond dimension: 16

# %%
using Plots
plot((0:nl) .* dt, expectations, xlabel="t", ylabel="Expectation", lw=2, label="Evaluate with belief propagation")

# %%
## A few more advanced options
# we will still do exactly the same evolution but also do loop correction for expectation values

# %%
# max bond dimension for the TN
# we will use enough and just see how
apply_kwargs = (maxdim=20, cutoff=1e-10, normalize=false)

# BP cache parameters
bp_update_kwargs =(maxiter=20, tol=1e-6, message_update=ms -> TN.make_eigs_real.(TN.default_message_update(ms)))
# Out:
# (maxiter = 20, tol = 1.0e-6, message_update = var"#7#8"())

# %%
# the initial state
ψ = TN.zerostate(g)

# create the BP cache manually
ψψ = TN.build_bp_cache(ψ; bp_update_kwargs...)

# an array to keep track of expectations
expectations_advanced = Float64[real(TN.expect(ψ, obs))]

# evolve! The first evaluation will take significantly longer because of compulation.
for l in 1:nl
    println("Layer $l")

    # pass BP cache manually
    # only update cache every `update_every` overlapping 2-qubit gates
    t1 = @timed ψ, ψψ = TN.apply(layer, ψ, ψψ; apply_kwargs, update_every=1, verbose=false);
    
    ## could also update outside 
    # t2 = @timed ψψ = TN.update(ψψ; bp_update_kwargs...)

    # push expectation to list
    # pass the cache instead of the state so that things don't have to update over and over
    push!(expectations_advanced, real(TN.expect(ψψ, obs; max_loop_size=4)))  # with some loop correction

    
    println("    Took time: $(t1.time) [s]. Max bond dimension: $(ITensorNetworks.maxlinkdim(ψ))")
end
# Out:
# Layer 1
#     Took time: 0.506245219 [s]. Max bond dimension: 2
# Layer 2
#     Took time: 0.528717309 [s]. Max bond dimension: 2
# Layer 3
#     Took time: 0.535730155 [s]. Max bond dimension: 2
# Layer 4
#     Took time: 0.528729482 [s]. Max bond dimension: 2
# Layer 5
#     Took time: 0.522494728 [s]. Max bond dimension: 2
# Layer 6
#     Took time: 0.526133353 [s]. Max bond dimension: 2
# Layer 7
#     Took time: 0.523259448 [s]. Max bond dimension: 2
# Layer 8
#     Took time: 0.537571285 [s]. Max bond dimension: 3
# Layer 9
#     Took time: 0.547607777 [s]. Max bond dimension: 3
# Layer 10
#     Took time: 0.544215587 [s]. Max bond dimension: 3
# Layer 11
#     Took time: 0.548733204 [s]. Max bond dimension: 3
# Layer 12
#     Took time: 0.565436777 [s]. Max bond dimension: 4
# Layer 13
#     Took time: 0.584758937 [s]. Max bond dimension: 4
# Layer 14
#     Took time: 0.58052644 [s]. Max bond dimension: 4
# Layer 15
#     Took time: 0.587263154 [s]. Max bond dimension: 4
# Layer 16
#     Took time: 0.584302405 [s]. Max bond dimension: 4
# Layer 17
#     Took time: 0.582552983 [s]. Max bond dimension: 4
# Layer 18
#     Took time: 0.579946471 [s]. Max bond dimension: 4
# Layer 19
#     Took time: 0.587705829 [s]. Max bond dimension: 5
# Layer 20
#     Took time: 0.610515521 [s]. Max bond dimension: 5
# Layer 21
#     Took time: 0.617543018 [s]. Max bond dimension: 5
# Layer 22
#     Took time: 0.636812503 [s]. Max bond dimension: 6
# Layer 23
#     Took time: 0.676986142 [s]. Max bond dimension: 6
# Layer 24
#     Took time: 0.695980229 [s]. Max bond dimension: 6
# Layer 25
#     Took time: 0.69593238 [s]. Max bond dimension: 6
# Layer 26
#     Took time: 0.720036387 [s]. Max bond dimension: 7
# Layer 27
#     Took time: 0.790904965 [s]. Max bond dimension: 7
# Layer 28
#     Took time: 0.841037766 [s]. Max bond dimension: 8
# Layer 29
#     Took time: 0.901931592 [s]. Max bond dimension: 8
# Layer 30
#     Took time: 0.905846455 [s]. Max bond dimension: 8
# Layer 31
#     Took time: 0.91746412 [s]. Max bond dimension: 8
# Layer 32
#     Took time: 0.955527169 [s]. Max bond dimension: 9
# Layer 33
#     Took time: 1.03783646 [s]. Max bond dimension: 9
# Layer 34
#     Took time: 1.103249134 [s]. Max bond dimension: 10
# Layer 35
#     Took time: 1.196937403 [s]. Max bond dimension: 10
# Layer 36
#     Took time: 1.232626483 [s]. Max bond dimension: 10
# Layer 37
#     Took time: 1.32038452 [s]. Max bond dimension: 10
# Layer 38
#     Took time: 1.357707942 [s]. Max bond dimension: 10
# Layer 39
#     Took time: 1.276090057 [s]. Max bond dimension: 10
# Layer 40
#     Took time: 1.377857401 [s]. Max bond dimension: 11
# Layer 41
#     Took time: 1.426567964 [s]. Max bond dimension: 11
# Layer 42
#     Took time: 1.561555103 [s]. Max bond dimension: 12
# Layer 43
#     Took time: 1.656649341 [s]. Max bond dimension: 12
# Layer 44
#     Took time: 1.965862061 [s]. Max bond dimension: 13
# Layer 45
#     Took time: 2.369132439 [s]. Max bond dimension: 13
# Layer 46
#     Took time: 2.74386383 [s]. Max bond dimension: 14
# Layer 47
#     Took time: 3.054334607 [s]. Max bond dimension: 15
# Layer 48
#     Took time: 3.294214987 [s]. Max bond dimension: 15
# Layer 49
#     Took time: 3.597679565 [s]. Max bond dimension: 16
# Layer 50
#     Took time: 3.903110509 [s]. Max bond dimension: 16

# %%
plot((0:nl) .* dt, expectations, xlabel="t", ylabel="Expectation", lw=2, label="Evaluate with belief propagation")
plot!((0:nl) .* dt, expectations_advanced, lw=2, label="With some loop corrections")
